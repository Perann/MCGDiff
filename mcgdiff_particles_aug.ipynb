# %% [markdown]
# # Monte Carlo Guided Diffusion with Particles
#
# This notebook implements the MCGDiff algorithm for the inverse problem of inpainting, utilizing the `particles` library for Sequential Monte Carlo (SMC) sampling. It mirrors the functionality of `mcgdiff_particles.py`.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import particles
from particles import state_space_models as ssm
from particles.core import FeynmanKac
from particles import distributions as dists
from particles import smc_samplers as ssp
from diffusers import UNet2DModel, DDPMScheduler
import torchvision.transforms as T
from tqdm.notebook import tqdm
from torchvision.datasets import CIFAR10
from torchvision.transforms import ToTensor

# Set device
device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cpu":
    import multiprocessing
    cores = multiprocessing.cpu_count()
    torch.set_num_threads(cores)
    print(f"Set torch num threads to {cores}")

print(f"Using device: {device}")
# Out:
# Set torch num threads to 22
# Using device: cpu

# %%
dataset = CIFAR10(root="./data", train=False, download=True, transform=ToTensor())

# %%
# Configuration
class Config:
    steps = 50          # Number of diffusion/SMC steps
    particles = 200      # Number of particles
    sigma = 5         # Observation noise sigma
    image_path = "images/emeu.jpeg"
    
config = Config()

# %%
# Helper Functions
from PIL import Image

def black_square(picture: torch.Tensor, n: int) -> torch.Tensor:
    """
    Add a black square of size (2n)x(2n) in the center of the picture.
    """
    if n <= 0:
        raise ValueError(f"n must be greater than 0 but got n={n}")

    pic = picture.clone()
    if pic.dim() == 2:
        H, W = pic.shape
        C = None
    elif pic.dim() == 3:
        C, H, W = pic.shape
    else:
        raise ValueError("picture must be 2D or 3D tensor")

    center_h, center_w = H // 2, W // 2
    h0 = center_h - n
    h1 = center_h + n
    w0 = center_w - n
    w1 = center_w + n

    if C is None:
        pic[h0:h1, w0:w1] = -1.0
    else:
        pic[:, h0:h1, w0:w1] = -1.0
    return pic

def load_image(path, size=256):
    try:
        img = Image.open(path).convert("RGB")
    except Exception as e:
        print(f"Could not load image at {path}, using dummy noise.")
        return torch.randn(1, 3, 256, 256).to(device)
        
    transform = T.Compose([
        T.Resize(size),
        T.CenterCrop(size),
        T.ToTensor(),
        T.Normalize([0.5], [0.5]) # Map to [-1, 1]
    ])
    return transform(img).unsqueeze(0).to(device)

def show_tensor_image(tensor, title=None):
    if isinstance(tensor, np.ndarray):
        tensor = torch.from_numpy(tensor)
    tensor = tensor.to("cpu").detach()
    if tensor.dim() == 4:
        tensor = tensor.squeeze(0)
    
    img = (tensor + 1) / 2
    img = img.clamp(0, 1)
    plt.imshow(img.permute(1, 2, 0))
    if title:
        plt.title(title)
    plt.axis('off')

# %%
# Load Model 
print("Loading model...")
model = UNet2DModel.from_pretrained(
    "google/ddpm-cifar10-32"
).to(device)

model.eval()
for p in model.parameters():
    p.requires_grad_(False)

scheduler = DDPMScheduler.from_pretrained(
    "google/ddpm-cifar10-32"
)
# Out:
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# Loading model...
# /home/smaug/Documents/MASTER/HiddenMarkovChain/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(

# %%
def show(img, title=None):
    if isinstance(img, np.ndarray):
        img = torch.from_numpy(img)

    img = img.detach().cpu()

    # Handle (1, C, H, W) or (C, H, W)
    if img.dim() == 4:
        img = img.squeeze(0)
    elif img.dim() != 3:
        raise ValueError(f"Unexpected image shape: {img.shape}")

    img = (img + 1) / 2
    img = img.clamp(0, 1)
    img = img.permute(1, 2, 0)

    plt.imshow(img)
    if title:
        plt.title(title)
    plt.axis("off")

# %%
print(f"Loading observation...")

gt_image = dataset[1][0].unsqueeze(0).to(device)
show(gt_image, "Ground Truth")
# Out:
# Loading observation...

# %%
# Create Mask and Observation
n = 5 
mask = torch.ones_like(gt_image)
_, _, H, W = gt_image.shape
center_h, center_w = H // 2, W // 2
h0 = center_h - n
h1 = center_h + n
w0 = center_w - n
w1 = center_w + n

mask[:, :, h0:h1, w0:w1] = 0.0
observation = gt_image * mask 

# Visualize
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
show_tensor_image(gt_image, "Ground Truth")
plt.subplot(1, 2, 2)
show_tensor_image(observation, "Observation")
plt.show()

# %%
# Particles Classes

class DiffusionDist(dists.ProbDist):
    def __init__(self, model, scheduler, t_diff, x_t):
        self.model = model
        self.scheduler = scheduler
        self.t_diff = t_diff # Current diffusion timestep (scalar integer)
        self.x_t = x_t       # Current particles (N, C, H, W)

    def rvs(self, size=None):
        # size is typically N (number of particles). 
        # x_t should already have size N.
        
        self.model.eval()
        
        with torch.no_grad():
            x_t_tensor = torch.from_numpy(self.x_t).to(device).float()
            N = x_t_tensor.shape[0]
            
            # Predict noise
            t_tensor = torch.full((N,), self.t_diff, device=device, dtype=torch.long)
            model_output = self.model(x_t_tensor, t_tensor).sample
            
            # Compute previous image x_{t-1}
            output = self.scheduler.step(model_output, self.t_diff, x_t_tensor)
            prev_sample = output.prev_sample
            
            return prev_sample.cpu().numpy()

    def logpdf(self, x):
        return np.zeros(x.shape[0]) 

class DiffusionFeynmanKac(FeynmanKac):
    def __init__(self, model, scheduler, observation, mask, T_steps, img_shape):
        self.model = model
        self.scheduler = scheduler
        self.observation = observation.cpu().numpy() # (1, C, H, W)
        self.mask = mask.cpu().numpy()               # (1, C, H, W) - 1 for valid pixels, 0 for missing
        self.T_steps = T_steps
        self.img_shape = img_shape #(C, H, W)
    
    @property
    def T(self):
        return self.T_steps

    def M0(self, N):
        # x_T ~ N(0, I)
        return np.random.randn(N, *self.img_shape)

    def M(self, t, xp):
        # Transition from t to t+1
        current_diff_t = self.T_steps - 1 - t
        dist = DiffusionDist(self.model, self.scheduler, current_diff_t, xp)
        return dist.rvs()

    def logG(self, t, xp, x):
        # Weighting function.
        # Note: Base implementation, typically overridden by Spaced version
        return np.zeros(x.shape[0])

# %%
# Spaced Diffusion Implementation
scheduler.set_timesteps(num_inference_steps=config.steps)

class SpacedDiffusionFeynmanKac(DiffusionFeynmanKac):
    def M(self, t, xp):
        current_timestep = self.scheduler.timesteps[t]
        dist = DiffusionDist(self.model, self.scheduler, current_timestep, xp)
        return dist.rvs()

    def logG(self, t, xp, x):
        if t + 1 < len(self.scheduler.timesteps):
            current_timestep = self.scheduler.timesteps[t+1]
            self.model.eval()
            with torch.no_grad():
                x_tensor = torch.from_numpy(x).to(device).float()
                N = x.shape[0]
                t_tensor = torch.full((N,), current_timestep, device=device, dtype=torch.long)
                model_output = self.model(x_tensor, t_tensor).sample
                alpha_bar = self.scheduler.alphas_cumprod[current_timestep].to(device)
                # Estimate x0
                pred_x0 = (x_tensor - torch.sqrt(1 - alpha_bar) * model_output) / torch.sqrt(alpha_bar)
                pred_x0 = pred_x0.clamp(-1, 1)
        else:
            pred_x0 = torch.from_numpy(x).to(device).float()
        
        y_tensor = torch.from_numpy(self.observation).to(device).float()
        mask_tensor = torch.from_numpy(self.mask).to(device).float()
        
        # Compute MSE on valid pixels only (mask=1 for valid, but here we enforce consistency with observation)
        # The mask used in code was 0 for missing, so observation = gt * mask.
        # In likelihood we want to enforce x0 match observation where mask=1.
        diff = (pred_x0 - y_tensor) * mask_tensor
        num_obs = mask_tensor.sum(dim=(1,2,3))
        mse = torch.sum(diff**2, dim=(1,2,3)) / (num_obs + 1e-8)
        log_weights = - mse / (2 * config.sigma**2)
        return log_weights.cpu().numpy()

# %%
# setup model
fk_model = SpacedDiffusionFeynmanKac(
    model=model, 
    scheduler=scheduler, 
    observation=observation, 
    mask=mask, 
    T_steps=len(scheduler.timesteps), 
    img_shape=gt_image.shape[1:]
)

# Run SMC
print(f"Running SMC with {config.particles} particles and {config.steps} steps...")
alg = particles.SMC(
    fk=fk_model,
    N=config.particles,
    ESSrmin=0.1,  
    verbose=True
)
alg.run()
# Out:
# Running SMC with 200 particles and 50 steps...
# t=0: resample:False, ESS (end of iter)=200.00
# t=1: resample:False, ESS (end of iter)=199.99
# t=2: resample:False, ESS (end of iter)=199.98
# t=3: resample:False, ESS (end of iter)=199.97
# t=4: resample:False, ESS (end of iter)=199.95
# t=5: resample:False, ESS (end of iter)=199.93
# t=6: resample:False, ESS (end of iter)=199.90
# t=7: resample:False, ESS (end of iter)=199.87
# t=8: resample:False, ESS (end of iter)=199.83
# t=9: resample:False, ESS (end of iter)=199.78
# t=10: resample:False, ESS (end of iter)=199.71
# t=11: resample:False, ESS (end of iter)=199.64
# t=12: resample:False, ESS (end of iter)=199.56
# t=13: resample:False, ESS (end of iter)=199.46
# t=14: resample:False, ESS (end of iter)=199.34
# t=15: resample:False, ESS (end of iter)=199.21
# t=16: resample:False, ESS (end of iter)=199.05
# t=17: resample:False, ESS (end of iter)=198.87
# t=18: resample:False, ESS (end of iter)=198.68
# t=19: resample:False, ESS (end of iter)=198.46
# t=20: resample:False, ESS (end of iter)=198.23
# t=21: resample:False, ESS (end of iter)=197.97
# t=22: resample:False, ESS (end of iter)=197.69
# t=23: resample:False, ESS (end of iter)=197.39
# t=24: resample:False, ESS (end of iter)=197.07
# t=25: resample:False, ESS (end of iter)=196.73
# t=26: resample:False, ESS (end of iter)=196.38
# t=27: resample:False, ESS (end of iter)=196.01
# t=28: resample:False, ESS (end of iter)=195.61
# t=29: resample:False, ESS (end of iter)=195.20
# t=30: resample:False, ESS (end of iter)=194.77
# t=31: resample:False, ESS (end of iter)=194.32
# t=32: resample:False, ESS (end of iter)=193.85
# t=33: resample:False, ESS (end of iter)=193.37
# t=34: resample:False, ESS (end of iter)=192.88
# t=35: resample:False, ESS (end of iter)=192.36
# t=36: resample:False, ESS (end of iter)=191.83
# t=37: resample:False, ESS (end of iter)=191.28
# t=38: resample:False, ESS (end of iter)=190.72
# t=39: resample:False, ESS (end of iter)=190.14
# t=40: resample:False, ESS (end of iter)=189.55
# t=41: resample:False, ESS (end of iter)=188.95
# t=42: resample:False, ESS (end of iter)=188.33
# t=43: resample:False, ESS (end of iter)=187.69
# t=44: resample:False, ESS (end of iter)=187.05
# t=45: resample:False, ESS (end of iter)=186.39
# t=46: resample:False, ESS (end of iter)=185.72
# t=47: resample:False, ESS (end of iter)=185.05
# t=48: resample:False, ESS (end of iter)=184.36
# t=49: resample:False, ESS (end of iter)=183.67

# %%
print("alg.X type:", type(alg.X))
print("alg.X len:", len(alg.X))
print("alg.X[-1].shape:", np.asarray(alg.X[-1]).shape)

print("alg.W[-1].shape:", np.asarray(alg.W[-1]).shape)
# Out:
# alg.X type: <class 'numpy.ndarray'>
# alg.X len: 200
# alg.X[-1].shape: (3, 32, 32)
# alg.W[-1].shape: ()

# %%
# Compute Weighted Mean Image

final_particles = alg.X        # (N, C, H, W)
weights = alg.W                # (N,)
weights = weights / weights.sum()

mean_img = np.tensordot(weights, final_particles, axes=(0, 0))

best_idx = np.argmax(weights)
best_img = final_particles[best_idx]

# Show ground truth, observation and best particle
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
show(observation, "Observation Image")
plt.subplot(1, 3, 2)
show(best_img, "Best Particle Image")
plt.subplot(1, 3, 3)
show(mean_img, "Weighted Mean Image")
plt.show()

# %%
mean_img_expanded = mean_img[None, ...]  # (1, C, H, W)

variance = np.tensordot(
    weights,
    (final_particles - mean_img_expanded) ** 2,
    axes=(0, 0)
)

std_dev = np.sqrt(np.sum(variance, axis=0))  # (H, W)


# Uncertainty Analysis
mean_img_expanded = mean_img[np.newaxis, ...]
variance = np.average((final_particles - mean_img_expanded)**2, axis=0, weights=weights)
std_dev = np.sqrt(variance).mean(axis=0)

plt.figure(figsize=(6, 6))
plt.imshow(std_dev, cmap='viridis')
plt.title("Pixelwise Uncertainty (Std Dev)")
plt.colorbar()
plt.axis('off')
plt.show()

# %% [markdown]
# ### WARM-START REFINEMENT WITH MORE DIFFUSION STEPS

# %%
# 1) Sauvegarde des particules et poids actuels
X_init = np.asarray(alg.X).copy()        # (N, C, H, W)
W_init = np.asarray(alg.W).copy()        # (N,)
W_init = W_init / W_init.sum()            # normalisation

print("Warm-start from particles:", X_init.shape)

# 2) Nouveau nombre de steps (raffinement)
refine_steps = 100   # tu peux essayer 50, 100, 200

scheduler_refine = DDPMScheduler.from_pretrained(
    "google/ddpm-cifar10-32"
)
scheduler_refine.set_timesteps(num_inference_steps=refine_steps)

# 3) Nouveau Feynman–Kac avec M0 warm-start
class WarmStartSpacedFK(SpacedDiffusionFeynmanKac):
    def M0(self, N):
        # On repart exactement des particules finales précédentes
        return X_init

    def logG(self, t, xp, x):
        """
        Même log-likelihood que précédemment,
        mais avec un sigma plus petit (guidage plus fort).
        """
        if t + 1 < len(self.scheduler.timesteps):
            current_timestep = self.scheduler.timesteps[t+1]
            with torch.no_grad():
                x_tensor = torch.from_numpy(x).to(device).float()
                N = x.shape[0]
                t_tensor = torch.full((N,), current_timestep, device=device, dtype=torch.long)
                model_output = self.model(x_tensor, t_tensor).sample
                alpha_bar = self.scheduler.alphas_cumprod[current_timestep].to(device)
                pred_x0 = (x_tensor - torch.sqrt(1 - alpha_bar) * model_output) / torch.sqrt(alpha_bar)
                pred_x0 = pred_x0.clamp(-1, 1)
        else:
            pred_x0 = torch.from_numpy(x).to(device).float()

        y_tensor = torch.from_numpy(self.observation).to(device).float()
        mask_tensor = torch.from_numpy(self.mask).to(device).float()

        diff = (pred_x0 - y_tensor) * mask_tensor
        num_obs = mask_tensor.sum(dim=(1,2,3))
        mse = torch.sum(diff**2, dim=(1,2,3)) / (num_obs + 1e-8)

        # 🔥 Guidage plus fort que précédemment
        sigma_refine = 1.0
        log_weights = - mse / (2 * sigma_refine**2)
        return log_weights.cpu().numpy()

# 4) Instanciation du nouveau modèle FK
fk_refine = WarmStartSpacedFK(
    model=model,
    scheduler=scheduler_refine,
    observation=observation,
    mask=mask,
    T_steps=len(scheduler_refine.timesteps),
    img_shape=gt_image.shape[1:]
)

# 5) Lancement du SMC de raffinement
print(f"Running warm-start SMC refinement with {config.particles} particles and {refine_steps} steps...")

alg_refine = particles.SMC(
    fk=fk_refine,
    N=config.particles,
    ESSrmin=0.1,
    verbose=True
)
alg_refine.run()
# Out:
# Warm-start from particles: (200, 3, 32, 32)
# /home/smaug/Documents/MASTER/HiddenMarkovChain/.venv/lib/python3.10/site-packages/huggingface_hub/utils/_validators.py:202: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Running warm-start SMC refinement with 200 particles and 100 steps...
# t=0: resample:False, ESS (end of iter)=170.62
# t=1: resample:False, ESS (end of iter)=105.82
# t=2: resample:False, ESS (end of iter)=62.30
# t=3: resample:False, ESS (end of iter)=42.06
# t=4: resample:False, ESS (end of iter)=32.78
# t=5: resample:False, ESS (end of iter)=28.22
# t=6: resample:False, ESS (end of iter)=25.74
# t=7: resample:False, ESS (end of iter)=24.20
# t=8: resample:False, ESS (end of iter)=23.21
# t=9: resample:False, ESS (end of iter)=22.55
# t=10: resample:False, ESS (end of iter)=22.07
# t=11: resample:False, ESS (end of iter)=21.66
# t=12: resample:False, ESS (end of iter)=21.23
# t=13: resample:False, ESS (end of iter)=20.82
# t=14: resample:False, ESS (end of iter)=20.43
# t=15: resample:False, ESS (end of iter)=20.03
# t=16: resample:False, ESS (end of iter)=19.63
# t=17: resample:True, ESS (end of iter)=199.62
# t=18: resample:False, ESS (end of iter)=198.52
# t=19: resample:False, ESS (end of iter)=196.81
# t=20: resample:False, ESS (end of iter)=194.42
# t=21: resample:False, ESS (end of iter)=191.59
# t=22: resample:False, ESS (end of iter)=188.50
# t=23: resample:False, ESS (end of iter)=185.27
# t=24: resample:False, ESS (end of iter)=181.91
# t=25: resample:False, ESS (end of iter)=178.60
# t=26: resample:False, ESS (end of iter)=175.27
# t=27: resample:False, ESS (end of iter)=171.78
# t=28: resample:False, ESS (end of iter)=168.22
# t=29: resample:False, ESS (end of iter)=164.65
# t=30: resample:False, ESS (end of iter)=160.93
# t=31: resample:False, ESS (end of iter)=157.21
# t=32: resample:False, ESS (end of iter)=153.26
# t=33: resample:False, ESS (end of iter)=149.40
# t=34: resample:False, ESS (end of iter)=145.61
# t=35: resample:False, ESS (end of iter)=141.74
# t=36: resample:False, ESS (end of iter)=137.96
# t=37: resample:False, ESS (end of iter)=134.04
# t=38: resample:False, ESS (end of iter)=130.13
# t=39: resample:False, ESS (end of iter)=126.26
# t=40: resample:False, ESS (end of iter)=122.42
# t=41: resample:False, ESS (end of iter)=118.64
# t=42: resample:False, ESS (end of iter)=114.85
# t=43: resample:False, ESS (end of iter)=111.02
# t=44: resample:False, ESS (end of iter)=107.27
# t=45: resample:False, ESS (end of iter)=103.55
# t=46: resample:False, ESS (end of iter)=99.87
# t=47: resample:False, ESS (end of iter)=96.27
# t=48: resample:False, ESS (end of iter)=92.68
# t=49: resample:False, ESS (end of iter)=89.14
# t=50: resample:False, ESS (end of iter)=85.79
# t=51: resample:False, ESS (end of iter)=82.65
# t=52: resample:False, ESS (end of iter)=79.69
# t=53: resample:False, ESS (end of iter)=76.75
# t=54: resample:False, ESS (end of iter)=73.94
# t=55: resample:False, ESS (end of iter)=71.31
# t=56: resample:False, ESS (end of iter)=68.81
# t=57: resample:False, ESS (end of iter)=66.34
# t=58: resample:False, ESS (end of iter)=64.02
# t=59: resample:False, ESS (end of iter)=61.81
# t=60: resample:False, ESS (end of iter)=59.68
# t=61: resample:False, ESS (end of iter)=57.64
# t=62: resample:False, ESS (end of iter)=55.65
# t=63: resample:False, ESS (end of iter)=53.73
# t=64: resample:False, ESS (end of iter)=51.89
# t=65: resample:False, ESS (end of iter)=50.16
# t=66: resample:False, ESS (end of iter)=48.53
# t=67: resample:False, ESS (end of iter)=46.96
# t=68: resample:False, ESS (end of iter)=45.47
# t=69: resample:False, ESS (end of iter)=44.03
# t=70: resample:False, ESS (end of iter)=42.61
# t=71: resample:False, ESS (end of iter)=41.22
# t=72: resample:False, ESS (end of iter)=39.90
# t=73: resample:False, ESS (end of iter)=38.64
# t=74: resample:False, ESS (end of iter)=37.46
# t=75: resample:False, ESS (end of iter)=36.34
# t=76: resample:False, ESS (end of iter)=35.28
# t=77: resample:False, ESS (end of iter)=34.24
# t=78: resample:False, ESS (end of iter)=33.24
# t=79: resample:False, ESS (end of iter)=32.27
# t=80: resample:False, ESS (end of iter)=31.35
# t=81: resample:False, ESS (end of iter)=30.47
# t=82: resample:False, ESS (end of iter)=29.63
# t=83: resample:False, ESS (end of iter)=28.83
# t=84: resample:False, ESS (end of iter)=28.06
# t=85: resample:False, ESS (end of iter)=27.34
# t=86: resample:False, ESS (end of iter)=26.64
# t=87: resample:False, ESS (end of iter)=25.98
# t=88: resample:False, ESS (end of iter)=25.36
# t=89: resample:False, ESS (end of iter)=24.75
# t=90: resample:False, ESS (end of iter)=24.18
# t=91: resample:False, ESS (end of iter)=23.63
# t=92: resample:False, ESS (end of iter)=23.11
# t=93: resample:False, ESS (end of iter)=22.62
# t=94: resample:False, ESS (end of iter)=22.14
# t=95: resample:False, ESS (end of iter)=21.68
# t=96: resample:False, ESS (end of iter)=21.24
# t=97: resample:False, ESS (end of iter)=20.82
# t=98: resample:False, ESS (end of iter)=20.42
# t=99: resample:False, ESS (end of iter)=20.03

# %%
final_particles = alg_refine.X        # (N, C, H, W)
weights = alg_refine.W                # (N,)
weights = weights / weights.sum()

mean_img = np.tensordot(weights, final_particles, axes=(0, 0))

best_idx = np.argmax(weights)
best_img = final_particles[best_idx]

# Show ground truth, observation and best particle
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
show(observation, "Observation Image")
plt.subplot(1, 3, 2)
show(best_img, "Best Particle Image")
plt.subplot(1, 3, 3)
show(mean_img, "Weighted Mean Image")
plt.show()

# %%
topk = np.argsort(weights)[-5:]
plt.figure(figsize=(10, 2))
for i, idx in enumerate(topk):
    plt.subplot(1, 5, i+1)
    show(final_particles[idx], f"#{i}")
plt.show()

# %%
import re 

ess_path = "result_ess_aug.txt"
ess_values = []
with open(ess_path, "r") as f:
    for line in f:
        ess = float(line.split("=")[-1])
        ess_values.append(ess)

# %%
plt.figure(figsize=(10, 5))

# Courbe ESS
plt.plot(ess_values, marker='o', label="ESS")

# Ligne verticale : reheat (début du warm-start refinement)
reheat_it = 50
plt.axvline(
    x=reheat_it,
    color="red",
    linestyle="--",
    linewidth=2,
    label="Warm-start"
)

# Ligne verticale : resampling à it = 50 + 17 = 67
resample_it = 67
plt.axvline(
    x=resample_it,
    color="blue",
    linestyle="--",
    linewidth=2,
    label="Resampling"
)

plt.title("Effective Sample Size (ESS) over SMC Steps")
plt.xlabel("SMC Step")
plt.ylabel("ESS")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
